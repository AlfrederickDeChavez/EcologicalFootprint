# %%
import pandas as pd

# %%
df = pd.read_csv('./EcologicalFootprint.csv')
df.head()
# Out:
#                Country                    Region  Population (millions)   HDI  \
# 0          Afghanistan  Middle East/Central Asia                  29.82  0.46
# 1              Albania   Northern/Eastern Europe                   3.16  0.73
# 2              Algeria                    Africa                  38.48  0.73
# 3               Angola                    Africa                  20.82  0.52
# 4  Antigua and Barbuda             Latin America                   0.09  0.78
#
#   GDP per Capita  Cropland Footprint  Grazing Footprint  Forest Footprint  \
# 0        $614.66                0.30               0.20              0.08
# 1      $4,534.37                0.78               0.22              0.25
# 2      $5,430.57                0.60               0.16              0.17
# 3      $4,665.91                0.33               0.15              0.12
# 4     $13,205.10                 NaN                NaN               NaN
#
# ...

# %%
df.loc[df['Country'] == 'Philippines']
# Out:
#          Country        Region  Population (millions)   HDI GDP per Capita  \
# 135  Philippines  Asia-Pacific                  96.71  0.66      $2,379.44
#
#      Cropland Footprint  Grazing Footprint  Forest Footprint  \
# 135                0.36               0.03              0.09
#
#      Carbon Footprint  Fish Footprint  ...  Cropland  Grazing Land  \
# 135              0.34            0.23  ...      0.32          0.02
#
#      Forest Land  Fishing Water  Urban Land  Total Biocapacity  \
# 135         0.09           0.07        0.05               0.54
#
#      Biocapacity Deficit or Reserve  Earths Required  Countries Required  \
# 135                           -0.56             0.64                2.03
#
#      Data Quality
# 135             5
#
# [1 rows x 21 columns]

# %%
df.loc[df['HDI'].nlargest(10).index]
# Out:
#          Country                   Region  Population (millions)   HDI  \
# 128       Norway  Northern/Eastern Europe                   4.99  0.94
# 8      Australia             Asia-Pacific                  23.05  0.93
# 163  Switzerland  Northern/Eastern Europe                   8.00  0.93
# 48       Denmark           European Union                   5.60  0.92
# 122  Netherlands           European Union                  16.71  0.92
# 32        Canada            North America                  34.84  0.91
# 67       Germany           European Union                  82.80  0.91
# 83       Ireland           European Union                   4.58  0.91
# 124  New Zealand             Asia-Pacific                   4.46  0.91
# 152    Singapore             Asia-Pacific                   5.30  0.91
#
#     GDP per Capita  Cropland Footprint  Grazing Footprint  Forest Footprint  \
# 128    $100,172.00                 NaN                NaN               NaN
# ...

# %%
df['Population (millions)'].nlargest(10)
# Out:
# 37     1408.04
# 79     1236.69
# 179     317.50
# 80      246.86
# 23      198.66
# 130     179.16
# 127     168.83
# 13      154.70
# 141     143.17
# 87      127.25
# Name: Population (millions), dtype: float64

# %%
df.columns = df.columns.str.replace('Population (millions)', 'Population')
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_8088/3526415375.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns = df.columns.str.replace('Population (millions)', 'Population')

# %%
df.head()
# Out:
#                Country                    Region  Population (millions)   HDI  \
# 0          Afghanistan  Middle East/Central Asia                  29.82  0.46
# 1              Albania   Northern/Eastern Europe                   3.16  0.73
# 2              Algeria                    Africa                  38.48  0.73
# 3               Angola                    Africa                  20.82  0.52
# 4  Antigua and Barbuda             Latin America                   0.09  0.78
#
#   GDP per Capita  Cropland Footprint  Grazing Footprint  Forest Footprint  \
# 0        $614.66                0.30               0.20              0.08
# 1      $4,534.37                0.78               0.22              0.25
# 2      $5,430.57                0.60               0.16              0.17
# 3      $4,665.91                0.33               0.15              0.12
# 4     $13,205.10                 NaN                NaN               NaN
#
# ...

# %%
df.loc[df['Biocapacity Deficit or Reserve'].nsmallest(10).index, ['Country', 'Biocapacity Deficit or Reserve', 'Population (millions)', 'Total Ecological Footprint', 'Total Biocapacity']]
# Out:
#                   Country  Biocapacity Deficit or Reserve  \
# 102            Luxembourg                          -14.14
# 7                   Aruba                          -11.31
# 138                 Qatar                           -9.56
# 152             Singapore                           -7.92
# 93                 Kuwait                           -7.58
# 178  United Arab Emirates                           -7.37
# 12                Bahrain                           -6.91
# 115            Montserrat                           -6.42
# 171   Trinidad and Tobago                           -6.36
# 16                Belgium                           -6.25
#
#      Population (millions)  Total Ecological Footprint  Total Biocapacity
# 102                  0.520                       15.82               1.68
# 7                    0.100                       11.88               0.57
# 138                  2.050                       10.80               1.24
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['Biocapacity Deficit or Reserve'].nlargest(10), df.loc[df['Biocapacity Deficit or Reserve'].nlargest(10).index,['Population (millions)']])
plt.xlabel(df['Biocapacity Deficit or Reserve'].nlargest(10).Country)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8088/1464829883.py in <module>
#       1 plt.plot(df['Biocapacity Deficit or Reserve'].nlargest(10), df.loc[df['Biocapacity Deficit or Reserve'].nlargest(10).index,['Population (millions)']])
# ----> 2 plt.xlabel(df['Biocapacity Deficit or Reserve'].nlargest(10).Country)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'Country'
